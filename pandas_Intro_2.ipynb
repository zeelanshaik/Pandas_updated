# %% [markdown]
# ## DataFrame Object

# %% [markdown]
# DataFrame is the a main object in pandas.It is used to represent data with rows and columns(tabular or excel spreadshee like data

# %%
#Imprting pandas module
import pandas as pd
import numpy as np

# %%
#Now read a csv file
d=pd.read_csv('datasets/weather.csv')
#print dataframe "d"
d.head(6)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
#
# ...

# %%
d.head(6)
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
# 5  2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain         9.222222
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
# 5                  7.111111      0.85            13.9587
#
# ...

# %% [markdown]
# ### Creating DataFrame with dictionary
#   * You can also create DataFrame with python dictionary very easily.
#   * You just need to call DataFrame() function and pass the dictionary as a argument in the function.
#   * <b>Note:</b> Notice one thing that i have taken all the columns of same length because you can not make dataframe object if your dictionary has variable column length

# %%
d.shape
# Out:
# (96453, 12)

# %%
r,c =d.shape

# %%
print(r)
# Out:
# 96453

# %%
print(c)
# Out:
# 12

# %%
# row-count * column-count

# %%
print(d.size)
# Out:
# 1157436

# %%
print(d.ndim)
# Out:
# 2

# %%
print(d.axes)
# Out:
# [RangeIndex(start=0, stop=96453, step=1), Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')]

# %%
d.columns
# Out:
# Index(['Formatted Date', 'Summary', 'Precip Type', 'Temperature (C)',
#        'Apparent Temperature (C)', 'Humidity', 'Wind Speed (km/h)',
#        'Wind Bearing (degrees)', 'Visibility (km)', 'Loud Cover',
#        'Pressure (millibars)', 'Daily Summary'],
#       dtype='object')

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
# Formatted Date              96453 non-null object
# Summary                     96453 non-null object
# Precip Type                 95936 non-null object
# Temperature (C)             96453 non-null float64
# Apparent Temperature (C)    96453 non-null float64
# Humidity                    96453 non-null float64
# Wind Speed (km/h)           96453 non-null float64
# Wind Bearing (degrees)      96453 non-null float64
# Visibility (km)             96453 non-null float64
# Loud Cover                  96453 non-null float64
# Pressure (millibars)        96453 non-null float64
# Daily Summary               96453 non-null object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %%
d["Summary"].head(4)
# Out:
# 0    Partly Cloudy
# 1    Partly Cloudy
# 2    Mostly Cloudy
# 3    Partly Cloudy
# Name: Summary, dtype: object

# %%
#Creatiing my own dictionary
mydict={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }
#Converting disction to dataframe object
df=pd.DataFrame(mydict)

#Printing the dataframe
df
# Out:
#       dates    day  temp  wind-speed
# 0  02-01-12  sunny    45          12
# 1  03-01-12  rainy    46          34
# 2  04-01-12    hot    47          45
# 3  05-01-12  sunny    48          56
# 4  06-01-12    hot    49          67

# %% [markdown]
# ### Shape of the dataframe
#   * <b>df.shape :</b> It will return a tuple (rows,columns)

# %%
df.shape
# Out:
# (5, 4)

# %% [markdown]
# ### Accessing columns :
#  * What if you want to print only two columns

# %%
df[['day','temp']]
# Out:
#      day  temp
# 0  sunny    45
# 1  rainy    46
# 2    hot    47
# 3  sunny    48
# 4    hot    49

# %% [markdown]
# ### Statistics of your dataframe
#  * You can see the statistics of your dataframe by calling describe() function
#  * It will print count of the columns,mean,SD,min,max etc..

# %%
d.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
# Formatted Date              96453 non-null object
# Summary                     96453 non-null object
# Precip Type                 95936 non-null object
# Temperature (C)             96453 non-null float64
# Apparent Temperature (C)    96453 non-null float64
# Humidity                    96453 non-null float64
# Wind Speed (km/h)           96453 non-null float64
# Wind Bearing (degrees)      96453 non-null float64
# Visibility (km)             96453 non-null float64
# Loud Cover                  96453 non-null float64
# Pressure (millibars)        96453 non-null float64
# Daily Summary               96453 non-null object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# ### Condition:
#  * To get dataframe where temperature is greater than 9

# %%
d1=d[d['Temperature (C)']>9]
d1
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 5      2006-04-01 05:00:00.000 +0200  Partly Cloudy        rain
# 8      2006-04-01 08:00:00.000 +0200  Partly Cloudy        rain
# 9      2006-04-01 09:00:00.000 +0200  Partly Cloudy        rain
# 10     2006-04-01 10:00:00.000 +0200  Partly Cloudy        rain
# 11     2006-04-01 11:00:00.000 +0200  Partly Cloudy        rain
# 12     2006-04-01 12:00:00.000 +0200  Partly Cloudy        rain
# 13     2006-04-01 13:00:00.000 +0200  Partly Cloudy        rain
# 14     2006-04-01 14:00:00.000 +0200  Partly Cloudy        rain
# 15     2006-04-01 15:00:00.000 +0200  Partly Cloudy        rain
# 16     2006-04-01 16:00:00.000 +0200  Partly Cloudy        rain
# 17     2006-04-01 17:00:00.000 +0200  Mostly Cloudy        rain
# ...

# %%
#How many rows and columns are there in 'd1'?
d1.shape
# Out:
# (56606, 12)

# %%
#Creatiing my own dictionary
mydict={
         'dates':['02-01-12','03-01-12','04-01-12','05-01-12','06-01-12'],
         'day':['sunny','rainy','hot','sunny','hot'],
         'wind-speed':[12,34,45,56,67],
         'temp':[45,46,47,48,49]
       }
#Converting disction to dataframe object
df=pd.DataFrame(mydict)

#Printing the dataframe
df
# Out:
#       dates    day  wind-speed  temp
# 0  02-01-12  sunny          12    45
# 1  03-01-12  rainy          34    46
# 2  04-01-12    hot          45    47
# 3  05-01-12  sunny          56    48
# 4  06-01-12    hot          67    49

# %% [markdown]
# ### Changing Index
#  * Pandas has its own indexing by default from 0 to row no
#  * We can also reset its index by set_index() function

# %%
df
# Out:
#       dates    day  temp  wind-speed
# 0  02-01-12  sunny    45          12
# 1  03-01-12  rainy    46          34
# 2  04-01-12    hot    47          45
# 3  05-01-12  sunny    48          56
# 4  06-01-12    hot    49          67

# %%
df.set_index('dates',inplace=True)
df1 = df.set_index('dates')

# %%
df
# Out:
#             day  temp  wind-speed
# dates
# 02-01-12  sunny    45          12
# 03-01-12  rainy    46          34
# 04-01-12    hot    47          45
# 05-01-12  sunny    48          56
# 06-01-12    hot    49          67

# %% [markdown]
# # Multiple indexing
#
# is defined as essential indexing because it deals with data analysis and manipulation, especially for working with higher dimensional data. It also enables us to store and manipulate data with the arbitrary number of dimensions in lower-dimensional data structures like Series and DataFrame.
#
# Multiple index Column
# In this example, two columns will be made as index column. Drop parameter is used to Drop the column and append parameter is used to append passed columns to the already existing index column.

# %%
data=df
data.set_index(["dates", "day"], inplace = True,
                            append = True, drop = False)
  
# display
data.head()
# Out:
#                      dates    day  wind-speed  temp
#   dates    day
# 0 02-01-12 sunny  02-01-12  sunny          12    45
# 1 03-01-12 rainy  03-01-12  rainy          34    46
# 2 04-01-12 hot    04-01-12    hot          45    47
# 3 05-01-12 sunny  05-01-12  sunny          56    48
# 4 06-01-12 hot    06-01-12    hot          67    49

# %% [markdown]
# #### Now we can find the specific value rows

# %%
df.loc['02-01-12']
# Out:
# day           sunny
# temp             45
# wind-speed       12
# Name: 02-01-12, dtype: object

# %%
df.iloc[4]
# Out:
# day           hot
# temp           49
# wind-speed     67
# Name: 06-01-12, dtype: object

# %%
df.iloc[0:3]
# Out:
#             day  temp  wind-speed
# dates
# 02-01-12  sunny    45          12
# 03-01-12  rainy    46          34
# 04-01-12    hot    47          45

# %%
df.reset_index()
# Out:
#       dates    day  temp  wind-speed
# 0  02-01-12  sunny    45          12
# 1  03-01-12  rainy    46          34
# 2  04-01-12    hot    47          45
# 3  05-01-12  sunny    48          56
# 4  06-01-12    hot    49          67

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f', 'h'],
                     columns=['one', 'two', 'three'])

# %%
df
# Out:
#         one       two     three
# a  0.272830  1.021383 -0.757293
# c  0.739330  0.808248 -0.937436
# e  0.143652 -0.640180  0.715196
# f  0.537161 -0.492591  0.698923
# h -1.526392 -1.284070  0.785434

# %%
df2=df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

# %%
df2
# Out:
#         one       two     three
# a  0.272830  1.021383 -0.757293
# b       NaN       NaN       NaN
# c  0.739330  0.808248 -0.937436
# d       NaN       NaN       NaN
# e  0.143652 -0.640180  0.715196
# f  0.537161 -0.492591  0.698923
# g       NaN       NaN       NaN
# h -1.526392 -1.284070  0.785434

# %%
pd.isna(df2['one'])
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g     True
# h    False
# Name: one, dtype: bool

# %% [markdown]
# # Working with the whole DataFrame

# %% [markdown]
# # DataFrame contents

# %%
df.info() # index & data types
n = 4
dfh = df.head(n) # get first n rows
dft = df.tail(n) # get last n rows
dfs = df.describe() # summary stats cols
top_left_corner_df = df.iloc[:5, :5]

# %% [markdown]
# # DataFrame non-indexing attributes

# %%
df = pd.DataFrame({
 'Rank' : [4.0, 3.0, 2.0, 1.0],
 'Marks' : [100, 200, 300, 400]
 })

# %%
df
# Out:
#    Rank  Marks
# 0   4.0    100
# 1   3.0    200
# 2   2.0    300
# 3   1.0    400

# %%
dfT = df.T # transpose rows and cols
print(dfT)
# Out:
#            0      1      2      3
# Rank     4.0    3.0    2.0    1.0
# Marks  100.0  200.0  300.0  400.0

# %%
l = df.axes # list row and col indexes
l
# Out:
# [RangeIndex(start=0, stop=4, step=1), Index(['Rank', 'Marks'], dtype='object')]

# %%
s = df.dtypes # Series column data types
print(s)
# Out:
# Rank     float64
# Marks      int64
# dtype: object
# False
# 2
# (4, 2)

# %%
b = df.empty # True for empty DataFrame
print(b)
# Out:
# False

# %%
i = df.ndim # number of axes (2)
print(i)
t = df.shape # (row-count, column-count)
print(t)
# Out:
# 2
# (4, 2)

# %% [markdown]
# # DataFrame utility methods

# %%
dfc = df.copy() # copy a DataFrame

dfc
# Out:
#    Rank  Marks
# 0   4.0    100
# 1   3.0    200
# 2   2.0    300
# 3   1.0    400

# %%
dfc1=df
dfc1
# Out:
#    Rank  Marks
# 0   4.0    100
# 1   3.0    200
# 2   2.0    300
# 3   1.0    400

# %% [markdown]
# # Rank()

# %%
dfc['new_rank'] =df['Marks'].rank(ascending=False)
dfc
# Out:
#    Rank  Marks  new_rank
# 0   4.0    100       4.0
# 1   3.0    200       3.0
# 2   2.0    300       2.0
# 3   1.0    400       1.0

# %% [markdown]
# # Create Class Quiz Score Data

# %%
class_quiz_data = {'name': ["Jamie", "Joe", "Jake", "Jill", "James", "Dan", "Joy", "Jared", "Jill", "Jaime", "Jay"],
                   'score': [80, 85, 74, 100, 98, 91, 89, 90, 65, 84, 85]
                  }
df_quiz_scores = pd.DataFrame(class_quiz_data)

# %% [markdown]
# The pandas series rank() method has another argument called pct that can be set to True or False. By default, it's False. This pct argument computes the percentage rank of data.
#
# To set the argument pct=True is similar to the NTILE(100) window function in SQL.
#
# PCT -percentile rankings!

# %%
df_quiz_scores
# Out:
#      name  score
# 0   Jamie     80
# 1     Joe     85
# 2    Jake     74
# 3    Jill    100
# 4   James     98
# 5     Dan     91
# 6     Joy     89
# 7   Jared     90
# 8    Jill     65
# 9   Jaime     84
# 10    Jay     85

# %%
#Lets create percentile based on my GPA or score on a quiz
df_quiz_scores['score_percent_rank'] = df_quiz_scores['score'].rank(pct=True)
df_quiz_scores
# Out:
#      name  score  score_percent_rank
# 0   Jamie     80            0.272727
# 1     Joe     85            0.500000
# 2    Jake     74            0.181818
# 3    Jill    100            1.000000
# 4   James     98            0.909091
# 5     Dan     91            0.818182
# 6     Joy     89            0.636364
# 7   Jared     90            0.727273
# 8    Jill     65            0.090909
# 9   Jaime     84            0.363636
# 10    Jay     85            0.500000

# %% [markdown]
# View df_quiz_scores as a dataframe below. Notice how a high quiz score by Dan of 91 has a rank value of 0.81. this as the 81st percentile.

# %%
#To make this rank easier to understand, I will multiply all these values by 100 and round to the nearest integer value.

df_quiz_scores['score_percentile_rank'] = (df_quiz_scores['score_percent_rank']*100).round()
df_quiz_scores
# Out:
#      name  score  score_percent_rank  score_percentile_rank
# 0   Jamie     80            0.272727                   27.0
# 1     Joe     85            0.500000                   50.0
# 2    Jake     74            0.181818                   18.0
# 3    Jill    100            1.000000                  100.0
# 4   James     98            0.909091                   91.0
# 5     Dan     91            0.818182                   82.0
# 6     Joy     89            0.636364                   64.0
# 7   Jared     90            0.727273                   73.0
# 8    Jill     65            0.090909                    9.0
# 9   Jaime     84            0.363636                   36.0
# 10    Jay     85            0.500000                   50.0

# %%
s = df_quiz_scores['score'].value_counts()
print(s)
# Out:
# 85     2
# 84     1
# 91     1
# 74     1
# 89     1
# 90     1
# 100    1
# 98     1
# 65     1
# 80     1
# Name: score, dtype: int64

# %% [markdown]
# # Maths on the whole DataFrame (not a complete list)

# %%
df = df.abs() # absolute values
df = df.add(o) # add df, Series or value
s = df.count() # non NA/null values
df = df.cummax() # (cols default axis)
df = df.cummin() # (cols default axis)
df = df.cumsum() # (cols default axis)
df = df.cumprod() # (cols default axis)
df = df.diff() # 1st diff (col def axis)
df = df.div(o) # div by df, Series, value
df = df.dot(o) # matrix dot product
s = df.max() # max of axis (col def)
s = df.mean() # mean (col default axis)
s = df.median()# median (col default)
s = df.min() # min of axis (col def)
df = df.mul(o) # mul by df Series val
s = df.sum() # sum axis (cols default)

# %%
s = df_quiz_scores.count()
print(s)
# Out:
# name                     11
# score                    11
# score_percent_rank       11
# score_percentile_rank    11
# dtype: int64

# %%
df = df_quiz_scores.cumsum()
df
# Out:
#                                             name score score_percent_rank  \
# 0                                          Jamie    80           0.272727
# 1                                       JamieJoe   165           0.772727
# 2                                   JamieJoeJake   239           0.954545
# 3                               JamieJoeJakeJill   339            1.95455
# 4                          JamieJoeJakeJillJames   437            2.86364
# 5                       JamieJoeJakeJillJamesDan   528            3.68182
# 6                    JamieJoeJakeJillJamesDanJoy   617            4.31818
# 7               JamieJoeJakeJillJamesDanJoyJared   707            5.04545
# 8           JamieJoeJakeJillJamesDanJoyJaredJill   772            5.13636
# 9      JamieJoeJakeJillJamesDanJoyJaredJillJaime   856                5.5
# 10  JamieJoeJakeJillJamesDanJoyJaredJillJaimeJay   941                  6
#
#    score_percentile_rank
# 0                     27
# 1                     77
# ...

# %%
df_quiz_scoresT=df_quiz_scores

df_quiz_scoresT['Diff'] = df_quiz_scoresT['score'].diff()
print(df_quiz_scoresT)
# Out:
#      name  score  score_percent_rank  score_percentile_rank  Diff
# 0   Jamie     80            0.272727                   27.0   NaN
# 1     Joe     85            0.500000                   50.0   5.0
# 2    Jake     74            0.181818                   18.0 -11.0
# 3    Jill    100            1.000000                  100.0  26.0
# 4   James     98            0.909091                   91.0  -2.0
# 5     Dan     91            0.818182                   82.0  -7.0
# 6     Joy     89            0.636364                   64.0  -2.0
# 7   Jared     90            0.727273                   73.0   1.0
# 8    Jill     65            0.090909                    9.0 -25.0
# 9   Jaime     84            0.363636                   36.0  19.0
# 10    Jay     85            0.500000                   50.0   1.0

# %% [markdown]
# # Working with Columns

# %% [markdown]
# Get column index and labels

# %%
idx = df_quiz_scores.columns # get col index
print(idx)
label = df_quiz_scores.columns[0] # 1st col label
print(label)
lst = df_quiz_scores.columns.tolist() # get as a list
print(lst)
# Out:
# Index(['name', 'score', 'score_percent_rank', 'score_percentile_rank', 'Diff'], dtype='object')
# name
# ['name', 'score', 'score_percent_rank', 'score_percentile_rank', 'Diff']

# %%
    # Create dataframe
    data = {'name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
            'year': [2012, 2012, 2013, 2014, 2014],
            'reports': [4, 24, 31, 2, 3],
            'coverage': [25, 94, 57, 62, 70]}

    df = pd.DataFrame(data, index = ['Cochice', 'Pima', 'Santa Cruz', 'Maricopa', 'Yuma'])
    print(); print(df)
# Out:
#              name  year  reports  coverage
# Cochice     Jason  2012        4        25
# Pima        Molly  2012       24        94
# Santa Cruz   Tina  2013       31        57
# Maricopa     Jake  2014        2        62
# Yuma          Amy  2014        3        70

# %% [markdown]
# # Selecting columns

# %%
s = df['colName'] # select col to Series
df = df[['colName']] # select col to df
df = df[['a','b']] # select 2 or more
df = df[['c','a','b']]# change order
s = df[df.columns[0]] # select by number
df = df[df.columns[[0, 3, 4]] # by number
s = df.pop('c') # get col & drop from df

# %%
s = df['name']
print(s)
#s.info()
# Out:
# Cochice       Jason
# Pima          Molly
# Santa Cruz     Tina
# Maricopa       Jake
# Yuma            Amy
# Name: name, dtype: object

# %%
datf = df[['name']]
print(datf)
# Out:
#              name
# Cochice     Jason
# Pima        Molly
# Santa Cruz   Tina
# Maricopa     Jake
# Yuma          Amy

# %%
#check whether a column in series or dataframe
if isinstance(s, pd.DataFrame):
        print("do stuff")
else:
        print("Dont do")
# Out:
# Dont do

# %%
datf
# Out:
#              name
# Cochice     Jason
# Pima        Molly
# Santa Cruz   Tina
# Maricopa     Jake
# Yuma          Amy

# %%
df
# Out:
#              name  year  reports  coverage
# Cochice     Jason  2012        4        25
# Pima        Molly  2012       24        94
# Santa Cruz   Tina  2013       31        57
# Maricopa     Jake  2014        2        62
# Yuma          Amy  2014        3        70

# %%
popdf = df.pop('name')
popdf
# Out:
# Cochice       Jason
# Pima          Molly
# Santa Cruz     Tina
# Maricopa       Jake
# Yuma            Amy
# Name: name, dtype: object

# %%
df
# Out:
#             year  reports  coverage
# Cochice     2012        4        25
# Pima        2012       24        94
# Santa Cruz  2013       31        57
# Maricopa    2014        2        62
# Yuma        2014        3        70

# %% [markdown]
# # Swap column contents – change column order

# %%
df[['B', 'A']] = df[['A', 'B']]

# %%
df['YearN'] = df['year']+1

# %%
df
# Out:
#              name  year  reports  coverage  YearN
# Cochice     Jason  2012        4        25   2013
# Pima        Molly  2012       24        94   2013
# Santa Cruz   Tina  2013       31        57   2014
# Maricopa     Jake  2014        2        62   2015
# Yuma          Amy  2014        3        70   2015

# %%
df[['YearN', 'year']] = df[['year', 'YearN']]
df
# Out:
#              name  year  reports  coverage  YearN
# Cochice     Jason  2013        4        25   2012
# Pima        Molly  2013       24        94   2012
# Santa Cruz   Tina  2014       31        57   2013
# Maricopa     Jake  2015        2        62   2014
# Yuma          Amy  2015        3        70   2014

# %% [markdown]
# # Dropping columns (mostly by label)

# %%
df = df.drop('col1', axis=1)
df.drop('col1', axis=1, inplace=True)
df = df.drop(['col1','col2'], axis=1)
s = df.pop('col') # drops from frame
del df['col'] # even classic python works
df.drop(df.columns[0], inplace=True)

# %%
df.drop('YearN', axis=1, inplace=True)
df
# Out:
#              name  year  reports  coverage
# Cochice     Jason  2013        4        25
# Pima        Molly  2013       24        94
# Santa Cruz   Tina  2014       31        57
# Maricopa     Jake  2015        2        62
# Yuma          Amy  2015        3        70

# %% [markdown]
# # Vectorised arithmetic on columns

# %%
df['proportion']=df['coverage']/df['reports']
df['percent'] = df['proportion'] * 100.0
df
# Out:
#              name  year  reports  coverage  proportion      percent
# Cochice     Jason  2013        4        25    6.250000   625.000000
# Pima        Molly  2013       24        94    3.916667   391.666667
# Santa Cruz   Tina  2014       31        57    1.838710   183.870968
# Maricopa     Jake  2015        2        62   31.000000  3100.000000
# Yuma          Amy  2015        3        70   23.333333  2333.333333

# %% [markdown]
# # Common column element-wise methods

# %%
s = df['col'].isnull()
s = df['col'].notnull() # not isnull()
s = df['col'].astype(float)
s = df['col'].round(decimals=0)
s = df['col'].diff(periods=1)
s = df['col'].shift(periods=1)
s = df['col'].to_datetime()
s = df['col'].fillna(0) # replace NaN w 0
s = df['col'].cumsum()
s = df['col'].cumprod()

# %%
s = df[['coverage']].isnull()
s
# Out:
#             coverage
# Cochice        False
# Pima           False
# Santa Cruz     False
# Maricopa       False
# Yuma           False

# %% [markdown]
# # Add Suffix to Each Column Name in Pandas DataFrame

# %%
import pandas as pd

data = {'Product': ['ABC','DDD','XYZ','AAA','CCC'],
          'Price': [750,430,980,250,620],
       'Discount': ['Yes','No','No','Yes','No']
        }

df = pd.DataFrame(data, columns = ['Product','Price','Discount'])
print (df)
# Out:
#   Product  Price Discount
# 0     ABC    750      Yes
# 1     DDD    430       No
# 2     XYZ    980       No
# 3     AAA    250      Yes
# 4     CCC    620       No

# %%
df = df.add_suffix('_Sold')
print (df)
# Out:
#   Product_Sold  Price_Sold Discount_Sold
# 0          ABC         750           Yes
# 1          DDD         430            No
# 2          XYZ         980            No
# 3          AAA         250           Yes
# 4          CCC         620            No

# %% [markdown]
# # Working with rows

# %%
df = pd.DataFrame({
 'col0' : [1.0, 2.0, 3.0, 4.0],
 'col1' : [100, 200, 300, 400],
 'col2' : [1, 200, 3, 400],
 'col3' : [1, 0, 3, -1],
 
 
 })
df
# Out:
#    col0  col1  col2  col3
# 0   1.0   100     1     1
# 1   2.0   200   200     0
# 2   3.0   300     3     3
# 3   4.0   400   400    -1

# %%
#Boolean row selection by values in a column
df = df[df['col0'] == 1.0]
print(df)
# Out:
#    col0  col1  col2  col3
# 0   1.0   100     1     1
